# %% [markdown]
#  # MACHINE LEARNING

# %% [markdown]
# ## Task 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing the Dataset

# %%
df=pd.read_csv('I:\ENTRI\Entri ML\ML Task 1\house_price.csv')
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## Describe

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        13200 non-null  object
#  1   size            13200 non-null  object
#  2   total_sqft      13200 non-null  float64
#  3   bath            13200 non-null  float64
#  4   price           13200 non-null  float64
#  5   bhk             13200 non-null  int64
#  6   price_per_sqft  13200 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 722.0+ KB

# %% [markdown]
# ## 1) Mean Function

# %%
# Calculating the Mean Value of price_per_sqft Column

mean =df.price_per_sqft.mean()
mean
# Out:
# 7920.336742424242

# %%
# Calculating the Median Value of price_per_sqft Column

median=df.price_per_sqft.median()
median
# Out:
# 5438.0

# %%
sns.distplot(df['price_per_sqft'],color='green')
plt.title('With Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\2696468632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'With Outliers')

# %%
# To see the Outliers Clearly use BOX PLOT

sns.boxplot(df['price_per_sqft'])
plt.title('With Outliers')
# Out:
# Text(0.5, 1.0, 'With Outliers')

# %%
df.price_per_sqft.quantile([0.1,0.25,0.50,0.75,0.90,0.92,0.93,0.94,0.95,0.96,0.97,0.98,0.99])
# Out:
# 0.10     3500.00
# 0.25     4267.00
# 0.50     5438.00
# 0.75     7317.00
# 0.90    11666.00
# 0.92    12857.00
# 0.93    13559.35
# 0.94    14394.80
# 0.95    15312.10
# 0.96    16500.00
# 0.97    17857.00
# 0.98    20000.00
# 0.99    23674.45
# Name: price_per_sqft, dtype: float64

# %%
#significant variation 98 & 99 percentile are present ,it indicates that ouliers are present in the dataset
df[df.price_per_sqft>df.price_per_sqft.quantile(0.95)]
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 48             KR Puram  2 Bedroom       800.0   1.0  130.0    2
# 69                other  3 Bedroom       500.0   3.0  100.0    3
# ...                 ...        ...         ...   ...    ...  ...
# 13142             other      2 BHK      1140.0   1.0  185.0    2
# 13157             other  7 Bedroom      1400.0   7.0  218.0    7
# 13185          Hulimavu      1 BHK       500.0   1.0  220.0    1
# 13186             other  4 Bedroom      1200.0   5.0  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 7               18181
# 9               36274
# 45              33333
# 48              16250
# 69              20000
# ...               ...
# ...

# %%
# To check dataframe without outliers
no_outliers=df[df.price_per_sqft<df.price_per_sqft.quantile(0.95)]
no_outliers
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# Plot no_ouliers variable to check the corrected outlers

sns.distplot(no_outliers['price_per_sqft'],color='green')
plt.title('Without Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\90403149.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(no_outliers['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'Without Outliers')

# %%
#visualise by Boxplot

sns.boxplot(no_outliers['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# Text(0.5, 1.0, 'No Outliers')

# %%
# To check the range of outliers
print('With Outliers:',len(df))
print('Without Outliers:',len(no_outliers))
print('Outliers:',len(df)-len(no_outliers))
# Out:
# With Outliers: 13200
# Without Outliers: 12540
# Outliers: 660

# %% [markdown]
# ## 2) Percentile Method

# %% [markdown]
# ### Displaying the column in distplot

# %%
sns.distplot(df['price_per_sqft'],color='green')
plt.title('With Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\2696468632.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'With Outliers')

# %% [markdown]
# ### Display the column in Box Plot

# %%
sns.boxplot(df['price_per_sqft'])
plt.title('With Outliers')
# Out:
# Text(0.5, 1.0, 'With Outliers')

# %% [markdown]
# ### Finding the Upper Limit

# %%
upper_limit=df['price_per_sqft'].quantile(0.99)
upper_limit
# Out:
# 23674.45000000001

# %% [markdown]
# ### Finding the lower limit

# %%
lower_limit=df['price_per_sqft'].quantile(0.05)
lower_limit
# Out:
# 3107.8500000000004

# %% [markdown]
# ### Detecting the Outliers

# %%
df.loc[(df['price_per_sqft']>upper_limit) | (df['price_per_sqft']<lower_limit)]
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0  370.00    6
# 20             Kengeri      1 BHK       600.0   1.0   15.00    1
# 41      Sarjapur  Road      3 BHK      1254.0   3.0   38.00    3
# 45          HSR Layout  8 Bedroom       600.0   9.0  200.00    8
# 89     Electronic City      2 BHK      1000.0   2.0   28.88    2
# ...                ...        ...         ...   ...     ...  ...
# 13127            other  4 Bedroom      1200.0   5.0  325.00    4
# 13155        Kothannur  4 Bedroom      1600.0   4.0   45.00    4
# 13185         Hulimavu      1 BHK       500.0   1.0  220.00    1
# 13186            other  4 Bedroom      1200.0   5.0  325.00    4
# 13199     Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 9               36274
# 20               2500
# 41               3030
# 45              33333
# 89               2888
# ...               ...
# ...

# %% [markdown]
# ### Trim or Delete Outliers in data

# %%
trim_outlier=df.loc[(df['price_per_sqft']<=upper_limit) & (df['price_per_sqft']<=upper_limit)]
print('Before Outliers:',len(df))
print('After Outliers:',len(trim_outlier))
print('Outliers:',len(df)-len(trim_outlier))
# Out:
# Before Outliers: 13200
# After Outliers: 13068
# Outliers: 132

# %% [markdown]
# ### After Outlier

# %%
sns.distplot(trim_outlier['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\1749104560.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(trim_outlier['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'No Outliers')

# %% [markdown]
# ### After Outlier

# %%
sns.boxplot(trim_outlier['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# Text(0.5, 1.0, 'No Outliers')

# %% [markdown]
# ## 3.Inter Quartile Range (IQR) Method

# %%
# To view the distplot

# %%
sns.distplot(df['price_per_sqft'],color='green')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\3092621572.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'],color='green')
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
# To view the Outliers on Boxplot

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %% [markdown]
# ### Calculate the Quartiles (Q1&Q2)

# %%
Q1=df.price_per_sqft.quantile(0.25)
Q3=df.price_per_sqft.quantile(0.75)
print('Q1;',Q1)
print('Q3;',Q3)
# Out:
# Q1; 4267.0
# Q3; 7317.0

# %% [markdown]
# ### Calculate the IQR

# %%
IQR=Q3-Q1
print('IQR=',IQR)
# Out:
# IQR= 3050.0

# %% [markdown]
# ### Define Lower Whisker and Upper Whisker

# %%
Lower_whisker=Q1-(1.5 * IQR)
Upper_Whisker=Q3+(1.5 * IQR)
print('Lower_Whisker:',Lower_whisker)
print('Upper_Whisker:',Upper_Whisker)
# Out:
# Lower_Whisker: -308.0
# Upper_Whisker: 11892.0

# %% [markdown]
# ### Finding the Outliers

# %%
df_iqr=df[(df.price_per_sqft<-308) | (df.price_per_sqft>11892)]
df_iqr
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 22          Thanisandra  4 Bedroom      2800.0   5.0  380.0    4
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 48             KR Puram  2 Bedroom       800.0   1.0  130.0    2
# ...                 ...        ...         ...   ...    ...  ...
# 13142             other      2 BHK      1140.0   1.0  185.0    2
# 13157             other  7 Bedroom      1400.0   7.0  218.0    7
# 13185          Hulimavu      1 BHK       500.0   1.0  220.0    1
# 13186             other  4 Bedroom      1200.0   5.0  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 7               18181
# 9               36274
# 22              13571
# 45              33333
# 48              16250
# ...               ...
# ...

# %%
df_Del_iqr=df[(df.price_per_sqft>-308) & (df.price_per_sqft<11892)]
df_Del_iqr
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print('Before Outliers:',len(df))
print('After Outliers:',len(df_Del_iqr))
print('Outliers:',len(df)-len(df_Del_iqr))
# Out:
# Before Outliers: 13200
# After Outliers: 11935
# Outliers: 1265

# %%
sns.distplot(df_Del_iqr['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\1939585681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_Del_iqr['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'No Outliers')

# %%
sns.boxplot(df_Del_iqr['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# Text(0.5, 1.0, 'No Outliers')

# %% [markdown]
# ## 4.Normal Distribution Method

# %%
# Find the Mean 
m=df.price_per_sqft.mean()
m
# Out:
# 7920.336742424242

# %%
# Find the Standard Deviation
s=df.price_per_sqft.std()
s
# Out:
# 106727.16032810867

# %%
# +3 signa
m+3*s
# Out:
# 328101.8177267502

# %%
# -3 signa
m-3*s
# Out:
# -312261.14424190175

# %% [markdown]
# ### Finding the Outliers

# %%
df[(df.price_per_sqft<-312261.14424190175) | (df.price_per_sqft>328101.8177267502)]
# Out:
#              location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345             other  3 Bedroom        11.0   3.0   74.0    3          672727
# 1106            other  5 Bedroom        24.0   2.0  150.0    5          625000
# 4044   Sarjapur  Road  4 Bedroom         1.0   4.0  120.0    4        12000000
# 4924            other      7 BHK         5.0   7.0  115.0    7         2300000
# 11447      Whitefield  4 Bedroom        60.0   4.0  218.0    4          363333

# %%
df_no_outlier=df[(df.price_per_sqft>-312261.14424190175) & (df.price_per_sqft<328101.8177267502)]
df_no_outlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print('Before Outliers:',len(df))
print('After Outliers:',len(df_no_outlier))
print('Outliers:',len(df)-len(df_no_outlier))
# Out:
# Before Outliers: 13200
# After Outliers: 13195
# Outliers: 5

# %%
sns.distplot(df_no_outlier['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\450246774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_no_outlier['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'No Outliers')

# %%
sns.boxplot(df_no_outlier['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# Text(0.5, 1.0, 'No Outliers')

# %% [markdown]
# ## 5.Z-Score Method

# %%
# Calculate the mean
mean=df.price_per_sqft.mean()
mean
# Out:
# 7920.336742424242

# %%
# Calculate the standard deviation
standard_deviation=df.price_per_sqft.std()
standard_deviation
# Out:
# 106727.16032810867

# %% [markdown]
# ### Finding the limit upper and lower

# %%
print('Upper_limit:',df['price_per_sqft'].mean() + 3 * df['price_per_sqft'].std())
print('Lower_limit:',df['price_per_sqft'].mean() - 3 * df['price_per_sqft'].std())
# Out:
# Upper_limit: 328101.8177267502
# Lower_limit: -312261.14424190175

# %% [markdown]
# ### Finding the Outliers

# %%
df[(df['price_per_sqft']>328101.8177267502) |(df['price_per_sqft']<-312261.14424190175)]
# Out:
#              location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345             other  3 Bedroom        11.0   3.0   74.0    3          672727
# 1106            other  5 Bedroom        24.0   2.0  150.0    5          625000
# 4044   Sarjapur  Road  4 Bedroom         1.0   4.0  120.0    4        12000000
# 4924            other      7 BHK         5.0   7.0  115.0    7         2300000
# 11447      Whitefield  4 Bedroom        60.0   4.0  218.0    4          363333

# %% [markdown]
# ### Without the Outliers

# %%
Z_no_Outliers=df[(df['price_per_sqft']<328101.8177267502) & (df['price_per_sqft']>-312261.14424190175)]
Z_no_Outliers
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print('Before Outliers:',len(df))
print('After Outliers:',len(Z_no_Outliers))
print('Outliers:',len(df)-len(Z_no_Outliers))
# Out:
# Before Outliers: 13200
# After Outliers: 13195
# Outliers: 5

# %%
sns.distplot(Z_no_Outliers['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# C:\Users\NOEL STERVIN\AppData\Local\Temp\ipykernel_31160\3554174269.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Z_no_Outliers['price_per_sqft'],color='green')
# Text(0.5, 1.0, 'No Outliers')

# %%
sns.boxplot(Z_no_Outliers['price_per_sqft'],color='green')
plt.title('No Outliers')
# Out:
# Text(0.5, 1.0, 'No Outliers')

# %%
## Selecting the Numeric Columns in DataFrame

numeric_columns=df.select_dtypes(include=['int','float']).columns
numeric_columns
# Out:
# Index(['total_sqft', 'bath', 'price', 'bhk', 'price_per_sqft'], dtype='object')

# %%
# Find the Corelation matrix
corr_matrix=df[numeric_columns].corr()
corr_matrix
# Out:
#                 total_sqft      bath     price       bhk  price_per_sqft
# total_sqft        1.000000  0.392743  0.574330  0.346013       -0.008267
# bath              0.392743  1.000000  0.455998  0.897951        0.030883
# price             0.574330  0.455998  1.000000  0.396883        0.028387
# bhk               0.346013  0.897951  0.396883  1.000000        0.030955
# price_per_sqft   -0.008267  0.030883  0.028387  0.030955        1.000000

# %% [markdown]
# ### Visualising it on a Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True ,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Visualising it on a Pairplot

# %%
sns.pairplot(df)
plt.title('Pair Plot')
plt.show()
